# %% [markdown]
# Exercise 2.5 - Hirann

# %%
n = 100
m = 0
sum = 0
while sum <= 5000:
    sum += n
    n += 10
    m += 1

months = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]
monty = months[m % 12 - 1]
years = (m - 1) // 12

print(f"Mrs A's account first became greater than $5000 on 1st of {monty} {2001 + years}")
